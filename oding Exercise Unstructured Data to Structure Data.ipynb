# %%
import pandas as pd
import re

# %%
df = pd.read_excel("C:/Users/0rame/Downloads/LM-Assignment-Test.xlsx",header=1)

# %%
df.head(3)
# Out:
#                  Time                                         Attributes
# 0 2024-08-18 07:59:30  sat=12  distance=0.0  totalDistance=1.74104492...
# 1 2024-08-18 08:00:47  sat=15  odometer=17849311  tripOdometer=0  fue...
# 2 2024-08-18 08:00:47  result=EC25AFAR05A06M4G  distance=0.0  totalDi...

# %%
def split_attributes(attributes):
    
    attr_dict = dict(re.findall(r'(\w+)=([\w\.]+)', str(attributes)))
    return attr_dict

parsed_attributes = df['Attributes'].apply(split_attributes)

attributes_df = pd.json_normalize(parsed_attributes)

structured_df = pd.concat([df['Time'], attributes_df], axis=1)


structured_df.to_csv('structured_output.csv', index=False)

# %%
structured_df
# Out:
#                     Time  sat distance  totalDistance motion  odometer  \
# 0    2024-08-18 07:59:30   12      0.0  1.741044923E7  false       NaN
# 1    2024-08-18 08:00:47   15      0.0  1.741044923E7  false  17849311
# 2    2024-08-18 08:00:47  NaN      0.0  1.741044923E7  false       NaN
# 3    2024-08-18 08:00:51   15      0.0  1.741044923E7  false  17849311
# 4    2024-08-18 08:59:32   11      0.0  1.741044923E7  false       NaN
# ...                  ...  ...      ...            ...    ...       ...
# 1601 2024-08-23 01:25:24  NaN      0.0  1.755868132E7   true  17982258
# 1602 2024-08-23 01:25:54   12   226.01  1.755890733E7   true  17982258
# 1603 2024-08-23 01:25:54  NaN      0.0  1.755890733E7   true  17982258
# 1604 2024-08-23 01:26:24   13   355.85  1.755926318E7   true  17982258
# 1605 2024-08-23 01:26:24  NaN      0.0  1.755926318E7   true  17982258
#
#      tripOdometer fuelConsumption  status            result ignition  \
# 0             NaN             NaN     NaN               NaN      NaN
# 1               0          177000     512               NaN      NaN
# 2             NaN             NaN     NaN  EC25AFAR05A06M4G      NaN
# 3               0          177000     512               NaN      NaN
# 4             NaN             NaN     NaN               NaN      NaN
# ...           ...             ...     ...               ...      ...
# 1601        20501          178282  266760               NaN     true
# 1602        20725          178282  266760               NaN      NaN
# 1603        20725          178282  266760               NaN     true
# 1604        21070          178282  266760               NaN      NaN
# 1605        21070          178282  266760               NaN     true
#
#      coolantTemp mapIntake   rpm obdSpeed intakeTemp fuel alarm
# 0            NaN       NaN   NaN      NaN        NaN  NaN   NaN
# 1            NaN       NaN   NaN      NaN        NaN  NaN   NaN
# 2            NaN       NaN   NaN      NaN        NaN  NaN   NaN
# 3            NaN       NaN   NaN      NaN        NaN  NaN   NaN
# 4            NaN       NaN   NaN      NaN        NaN  NaN   NaN
# ...          ...       ...   ...      ...        ...  ...   ...
# 1601         109        96   707        2         45    2   NaN
# 1602         NaN       NaN   NaN      NaN        NaN  NaN   NaN
# 1603         112        96  1311       38         40    2   NaN
# 1604         NaN       NaN   NaN      NaN        NaN  NaN   NaN
# 1605         108        96  1367       41         42    2   NaN
#
# [1606 rows x 18 columns]
